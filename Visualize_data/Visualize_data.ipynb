# %% [markdown]
# # **Visualize data with Matplotlib**

# %%
import pandas as pd

# %% [markdown]
# Load data from a text file

# %%
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv

df_students = pd.read_csv('grades.csv',delimiter=',',header='infer')
# Out:
# --2024-01-20 15:33:46--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [text/plain]
# Saving to: ‘grades.csv’
#
# grades.csv          100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-01-20 15:33:46 (5.47 MB/s) - ‘grades.csv’ saved [322/322]

# %% [markdown]
# Remove any rows with missing data

# %%
df_students = df_students.dropna(axis=0, how='any')

# %% [markdown]
# Calculate who passed, assuming '60' is the grade needed to pass

# %%
passes  = pd.Series(df_students['Grade'] >= 60)

# %% [markdown]
# Save who passed to the Pandas dataframe

# %%
df_students = pd.concat([df_students, passes.rename("Pass")], axis=1)

# %% [markdown]
#  Print the result out into this notebook

# %%
df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_students['StudyHours'].plot(kind='hist', bins=20, title='StudyHours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_students['Grade'].plot(kind='hist', bins=20, title='Grade')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_students.groupby('Pass').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_students.plot(kind='scatter', x='StudyHours', y='Grade', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_students['StudyHours'].plot(kind='line', figsize=(8, 4), title='StudyHours')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_students['Grade'].plot(kind='line', figsize=(8, 4), title='Grade')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_students['Pass'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_students, x='StudyHours', y='Pass', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_students['Pass'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_students, x='Grade', y='Pass', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_students['Pass'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_students, x='StudyHours', y='Pass', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-7-c252209c5b8e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df_students, x='StudyHours', y='Pass', inner='stick', palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_students['Pass'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_students, x='Grade', y='Pass', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-8-107a8a9bcc1e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df_students, x='Grade', y='Pass', inner='stick', palette='Dark2')

# %%
# %matplotlib inline

from matplotlib import pyplot as plt

# %%
plt.bar(x=df_students.Name, height=df_students.Grade)
# Out:
# <BarContainer object of 22 artists>

# %%
plt.show()

# %%
plt.bar(x=df_students.Name, height=df_students.Grade, color='orange')
# Out:
# <BarContainer object of 22 artists>

# %%
plt.title('Student Grades')

plt.xlabel('Student')

plt.ylabel('Grade')

plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)

plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.show()
fig = plt.figure(figsize=(8,3))
plt.bar(x=df_students.Name, height=df_students.Grade, color='orange')
# Out:
# <BarContainer object of 22 artists>

# %%
plt.title('Student Grades')

plt.xlabel('Student')

plt.ylabel('Grade')

plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)

plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.show()

fig, ax = plt.subplots(1, 2, figsize = (10,4))
ax[0].bar(x=df_students.Name, height=df_students.Grade, color='orange')

ax[0].set_title('Grades')

ax[0].set_xticklabels(df_students.Name, rotation=90)
# Out:
# <ipython-input-17-5ac659dee1d1>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(df_students.Name, rotation=90)
# [Text(0, 0, 'Dan'),
#  Text(1, 0, 'Joann'),
#  Text(2, 0, 'Pedro'),
#  Text(3, 0, 'Rosie'),
#  Text(4, 0, 'Ethan'),
#  Text(5, 0, 'Vicky'),
#  Text(6, 0, 'Frederic'),
#  Text(7, 0, 'Jimmie'),
#  Text(8, 0, 'Rhonda'),
#  Text(9, 0, 'Giovanni'),
#  Text(10, 0, 'Francesca'),
#  Text(11, 0, 'Rajab'),
#  Text(12, 0, 'Naiyana'),
#  Text(13, 0, 'Kian'),
#  Text(14, 0, 'Jenny'),
#  Text(15, 0, 'Jakeem'),
#  Text(16, 0, 'Helena'),
#  Text(17, 0, 'Ismat'),
#  Text(18, 0, 'Anila'),
#  Text(19, 0, 'Skye'),
#  Text(20, 0, 'Daniel'),
#  Text(21, 0, 'Aisha')]

# %%
pass_counts = df_students['Pass'].value_counts()

ax[1].pie(pass_counts, labels=pass_counts)

ax[1].set_title('Passing Grades')

ax[1].legend(pass_counts.keys().tolist())

# %%
fig.suptitle('Student Data')
fig.show()

df_students.plot.bar(x='Name', y='StudyHours', color='teal', figsize=(6,4))
# Out:
# <Axes: xlabel='Name'>

# %%
var_data = df_students['Grade']
fig = plt.figure(figsize=(10,4))
plt.hist(var_data)
plt.title('Data Distribution')

plt.xlabel('Value')

plt.ylabel('Frequency')
fig.show()
var = df_students['Grade']

# %%
min_val = var.min()

max_val = var.max()

mean_val = var.mean()

med_val = var.median()

mod_val = var.mode()[0]

print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,

                                                                                        mean_val,

                                                                                        med_val,

                                                                                        mod_val,

                                                                                        max_val))
# Out:
# Minimum:3.00
# Mean:49.18
# Median:49.50
# Mode:50.00
# Maximum:97.00

# %%
fig = plt.figure(figsize=(10,4))
plt.hist(var)
plt.axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)

plt.axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)

plt.axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)

plt.axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)

plt.axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

# %%
plt.title('Data Distribution')

plt.xlabel('Value')

plt.ylabel('Frequency')
fig.show()
var = df_students['Grade']
fig = plt.figure(figsize=(10,4))
plt.boxplot(var)
plt.title('Data Distribution')
fig.show()

# %%
def show_distribution(var_data):

    from matplotlib import pyplot as plt

    # Get statistics

    min_val = var_data.min()

    max_val = var_data.max()

    mean_val = var_data.mean()

    med_val = var_data.median()

    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,

                                                                                            mean_val,

                                                                                            med_val,

                                                                                            mod_val,

                                                                                            max_val))

# %%
fig, ax = plt.subplots(2, 1, figsize = (10,4))
ax[0].hist(var_data)

ax[0].set_ylabel('Frequency')
ax[0].axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)

ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)

ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)

ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)

ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)
ax[1].boxplot(var_data, vert=False)

ax[1].set_xlabel('Value')
# Out:
# Text(0.5, 0, 'Value')

# %%
 fig.suptitle('Data Distribution')
 fig.show()
 col = df_students['Grade']
 def show_density(var_data):

    from matplotlib import pyplot as plt

    fig = plt.figure(figsize=(10,4))

    # Plot density

    var_data.plot.density()

    # Add titles and labels

    plt.title('Data Density')

    # Show the mean, median, and mode

    plt.axvline(x=var_data.mean(), color = 'cyan', linestyle='dashed', linewidth = 2)

    plt.axvline(x=var_data.median(), color = 'red', linestyle='dashed', linewidth = 2)

    plt.axvline(x=var_data.mode()[0], color = 'yellow', linestyle='dashed', linewidth = 2)

# %%
show_distribution(col)
plt.show()
col = df_students['Grade']
show_density(col)
# Out:
# Minimum:3.00
# Mean:49.18
# Median:49.50
# Mode:50.00
# Maximum:97.00
